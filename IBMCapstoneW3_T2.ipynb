# %% [markdown]
# # Continue with Task number 2
# * import the package and data

# %%
import pandas as pd
post_df=pd.read_csv("post_df.csv")
lonlat=pd.read_csv("https://cocl.us/Geospatial_data")

# %% [markdown]
# * replace the columnname with the same
# * merge these two dataframes

# %%
lonlat=lonlat.rename(columns={"Postal Code":"Postcode"})
post_df_can=pd.merge(post_df,lonlat,how="left",on="Postcode")
post_df_can
# Out:
#     Postcode      Borough                                      Neighbourhood  \
# 0        M1B  Scarborough                                     Rouge, Malvern
# 1        M1C  Scarborough             Highland Creek, Rouge Hill, Port Union
# 2        M1E  Scarborough                  Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                             Woburn
# 4        M1H  Scarborough                                          Cedarbrae
# ..       ...          ...                                                ...
# 98       M9N         York                                             Weston
# 99       M9P    Etobicoke                                          Westmount
# 100      M9R    Etobicoke  Kingsview Village, Martin Grove Gardens, Richv...
# 101      M9V    Etobicoke  Albion Gardens, Beaumond Heights, Humbergate, ...
# 102      M9W    Etobicoke                                          Northwest
#
#       Latitude  Longitude
# ...

# %%
post_df_can.to_csv("post_df_can.csv",index=False)
